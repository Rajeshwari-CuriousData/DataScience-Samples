# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.1 KB

# %%
df.shape
# Out:
# (244, 7)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
column_df=df["total_bill"]
column_df
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
columns=df[["sex","time","day"]]
print(columns.head())
print(columns.tail())
# Out:
#       sex    time  day
# 0  Female  Dinner  Sun
# 1    Male  Dinner  Sun
# 2    Male  Dinner  Sun
# 3    Male  Dinner  Sun
# 4  Female  Dinner  Sun
#         sex    time   day
# 239    Male  Dinner   Sat
# 240  Female  Dinner   Sat
# 241    Male  Dinner   Sat
# 242    Male  Dinner   Sat
# 243  Female  Dinner  Thur

# %% [markdown]
# ##### loc & iloc

# %%
df.loc[0]
# Out:
# total_bill     16.99
# tip             1.01
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 0, dtype: object

# %%
df.loc[[1,2,5,99]]
# Out:
#     total_bill   tip   sex smoker  day    time  size
# 1        10.34  1.66  Male     No  Sun  Dinner     3
# 2        21.01  3.50  Male     No  Sun  Dinner     3
# 5        25.29  4.71  Male     No  Sun  Dinner     4
# 99       12.46  1.50  Male     No  Fri  Dinner     2

# %%
df.loc[[2,6,3,9,99],["total_bill","sex"]]
# Out:
#     total_bill   sex
# 2        21.01  Male
# 6         8.77  Male
# 3        23.68  Male
# 9        14.78  Male
# 99       12.46  Male

# %%
df["tip"]
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
df.loc[100,"tip"]
# Out:
# 2.5

# %%
df.loc[1:5,["day","tip"]]
# Out:
#    day   tip
# 1  Sun  1.66
# 2  Sun  3.50
# 3  Sun  3.31
# 4  Sun  3.61
# 5  Sun  4.71

# %%
df.loc[1:10,["sex","day","tip"]]
# Out:
#        sex  day   tip
# 1     Male  Sun  1.66
# 2     Male  Sun  3.50
# 3     Male  Sun  3.31
# 4   Female  Sun  3.61
# 5     Male  Sun  4.71
# 6     Male  Sun  2.00
# 7     Male  Sun  3.12
# 8     Male  Sun  1.96
# 9     Male  Sun  3.23
# 10    Male  Sun  1.71

# %%
df.loc[1:6,"tip":"size"]
# Out:
#     tip     sex smoker  day    time  size
# 1  1.66    Male     No  Sun  Dinner     3
# 2  3.50    Male     No  Sun  Dinner     3
# 3  3.31    Male     No  Sun  Dinner     2
# 4  3.61  Female     No  Sun  Dinner     4
# 5  4.71    Male     No  Sun  Dinner     4
# 6  2.00    Male     No  Sun  Dinner     2

# %%
df.iloc[-2]
# Out:
# total_bill     17.82
# tip             1.75
# sex             Male
# smoker            No
# day              Sat
# time          Dinner
# size               2
# Name: 242, dtype: object

# %%
df.iloc[1:5,1:5]
# Out:
#     tip     sex smoker  day
# 1  1.66    Male     No  Sun
# 2  3.50    Male     No  Sun
# 3  3.31    Male     No  Sun
# 4  3.61  Female     No  Sun

# %%
df.iloc[[1,3,5,7,9,11,13],[1,5]]
# Out:
#      tip    time
# 1   1.66  Dinner
# 3   3.31  Dinner
# 5   4.71  Dinner
# 7   3.12  Dinner
# 9   3.23  Dinner
# 11  5.00  Dinner
# 13  3.00  Dinner

# %%
df.loc[1,["day","tip"]]
# Out:
# day     Sun
# tip    1.66
# Name: 1, dtype: object

# %%
df.iloc[1:11,1:5]
# Out:
#      tip     sex smoker  day
# 1   1.66    Male     No  Sun
# 2   3.50    Male     No  Sun
# 3   3.31    Male     No  Sun
# 4   3.61  Female     No  Sun
# 5   4.71    Male     No  Sun
# 6   2.00    Male     No  Sun
# 7   3.12    Male     No  Sun
# 8   1.96    Male     No  Sun
# 9   3.23    Male     No  Sun
# 10  1.71    Male     No  Sun

# %%
r=list(range(5))
print(df.iloc[r,:])
#print(df.iloc[r,r])
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df[::]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df[:]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.loc[5,"day"]
# Out:
# 'Sun'

# %%
df.iloc[7,5]
# Out:
# 'Dinner'

# %% [markdown]
# #### groupby()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.groupby(["sex","time","day"])["total_bill","tip"].mean().head(10)
# Out:
# C:\Users\SRAM21\AppData\Local\Temp/ipykernel_7412/1749234847.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["sex","time","day"])["total_bill","tip"].mean().head(10)
#                     total_bill       tip
# sex    time   day
# Male   Lunch  Thur   18.714667  2.980333
#               Fri    11.386667  1.900000
#               Sat          NaN       NaN
#               Sun          NaN       NaN
#        Dinner Thur         NaN       NaN
#               Fri    23.487143  3.032857
#               Sat    20.802542  3.083898
#               Sun    21.887241  3.220345
# Female Lunch  Thur   16.648710  2.561935
#               Fri    13.940000  2.745000

# %%
df[df["tip"]<20].shape
# Out:
# (244, 7)

# %%
df.groupby("sex")["total_bill"].mean()
# Out:
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %%
t=df.groupby("size")["tip"].mean()
t
t.plot()
# Out:
# <AxesSubplot:xlabel='size'>
